# %%
import scraper
import os
import re
import datetime
import typing
from time import sleep
import pickle
import statistics

from dotenv import load_dotenv
from github import Github, Repository, ContentFile, RateLimitExceededException, GithubException
from typing import List

# %%
auth_file_regex_pattern = ".*?(auth|login|oidc|session).*?\.(ts|js)"
auth_regex = re.compile(auth_file_regex_pattern)

dir_patterns = ["auth", "oidc", "login", "session", "src", "server", "srv", "app", "middleware", "services", "service"]

query1 = "oidc-client filename:package.json path:/ express filename:package.json"
query2 = "openid-client filename:package.json path:/ express filename:package.json"

queries = [query1, query2]
load_dotenv()
# Out:
# True

# %%
def find_repos_for(query, token):
    g = Github(token)
    result = g.search_code(query=query)
    repos = []
    for i in range(0, result.totalCount):
        success = False
        while not success:
            try:
                repos += result.get_page(i)
                success = True
            except RateLimitExceededException as e:
                reset_at = datetime.datetime.fromtimestamp(float(e.headers["x-ratelimit-reset"]))
                reset_in = (reset_at - datetime.datetime.now())
                reset_in_seconds = min(reset_in.seconds + 5, 600)
                print(
                    f"Github error = {e.data} "
                    f"x-ratelimit-limit = {e.headers['x-ratelimit-limit']}  "
                    f"x-ratelimit-remaining = {e.headers['x-ratelimit-remaining']} "
                    f"x-ratelimit-reset = {e.headers['x-ratelimit-reset']} ({reset_in.seconds}s)")
                print(f"ratelimit hit, waiting {reset_in_seconds} sec...")
                sleep(reset_in_seconds) # TODO do we miss a page here
            except GithubException as e:
                print(f"Github exception {e.data}")
                print("Halting search and returning results found")
                return repos
    return repos


def find_auth_files(repo: Repository) -> typing.List:
    print(f"Searching for auth files for repo = {repo.url}")
    try:
        root_contents = repo.get_contents("")
        return search_repo_files(root_contents, repo)
    except GithubException as ge:
        if ge.status == 403:
            print(f"Access denied for repo, skipping: {ge}")
        else:
            raise ge


def search_repo_files(root_contents, repo):
    auth_files = []
    while root_contents:
        file_content = root_contents.pop(0)
        if file_content.type == "dir" and is_server_or_auth_dir(file_content.name):
            root_contents.extend(repo.get_contents(file_content.path))
        else:
            if is_auth_file(file_content.name):
                print(f"auth file = {file_content.name} found for repo = {repo.name}")
                auth_files.append((file_content, file_loc(file_content)))
    return auth_files


def is_auth_file(name: str) -> bool:
    return True if auth_regex.match(name) else False


def is_server_or_auth_dir(name: str) -> bool:
    for pattern in dir_patterns:
        if pattern in name:
            return True
    return False


def avg_loc(files):
    summer = 0
    for file in files:
        summer += file_loc(file)
    return summer


def file_loc(file: ContentFile):
    return len(file.decoded_content.split(b"\n"))


def store_repos(repositories):
    with open("data/repos_store.pickle", 'wb') as store:
        pickle.dump(repositories, store)


def load_repos() -> List[Repository.Repository]:
    with open("data/repos_store.pickle", 'rb') as store:
        return pickle.load(store)

# %%
# using an access token
g = Github(os.getenv("AITM_TOKEN"))
repo_to_auth_files = {}
try:
    for query in queries:
        print(f"AitM Scraper running query = {query}")
        result = g.search_code(query=query)
        print(f"Total results from query = {result.totalCount}")

        for i in range(0, result.totalCount):
            page = result.get_page(i)

            # create a mapping of repos to likely authentication related source files (js, ts) in the repo
            new = {file.repository: find_auth_files(file.repository) for file in page}
            repo_to_auth_files = {**repo_to_auth_files, **new}
    repo_to_auth_files = dict(filter(lambda elem: len(elem[1]) > 0, repo_to_auth_files.items()))
    print(f"result nr = {len(repo_to_auth_files)}")
    print(repo_to_auth_files)
except RateLimitExceededException as e:
    print(e)
# Out:
# AitM Scraper running query = oidc-client filename:package.json path:/ express filename:package.json
# Total results from query = 91
# Searching for auth files for repo = https://api.github.com/repos/DFE-Digital/login.dfe.examples.oidc-client
# Searching for auth files for repo = https://api.github.com/repos/philiplinell/oidc-client
# auth file = oidc.js found for repo = oidc-client
# Searching for auth files for repo = https://api.github.com/repos/the-watchmen/node-oidc-proxy
# Searching for auth files for repo = https://api.github.com/repos/zapnito/oidc-client-js
# Searching for auth files for repo = https://api.github.com/repos/linz/oidc-client-js
# Searching for auth files for repo = https://api.github.com/repos/fmoraw/oicdjs
# Searching for auth files for repo = https://api.github.com/repos/IdentityModel/oidc-client-js
# Searching for auth files for repo = https://api.github.com/repos/moomoo-ya/oidc-client-sample
# Searching for auth files for repo = https://api.github.com/repos/smartworld-dm/oidc-client
# Searching for auth files for repo = https://api.github.com/repos/sknoslo/cypress-oidc-client
# auth file = oidc.js found for repo = cypress-oidc-client
# Searching for auth files for repo = https://api.github.com/repos/Orthodox-Union/js-utils
# Searching for auth files for repo = https://api.github.com/repos/IAmAnubhavSaini/IdentityModel_oidc-client-js
# Searching for auth files for repo = https://api.github.com/repos/IAmAnubhavSaini/IdentityModel_oidc-client-js
# Searching for auth files for repo = https://api.github.com/repos/onigra/vue-fes-japan-reject-con-demo
# Searching for auth files for repo = https://api.github.com/repos/LykkeCorp/lykke.com
# auth file = authService.js found for repo = lykke.com
# Searching for auth files for repo = https://api.github.com/repos/medaminehamidi/portfolio
# auth file = auth.js found for repo = portfolio
# Searching for auth files for repo = https://api.github.com/repos/ComputerScienceHouse/Vote
# Searching for auth files for repo = https://api.github.com/repos/nikolai-git-house/Reed-NextJs-frontend
# auth file = auth.js found for repo = Reed-NextJs-frontend
# Searching for auth files for repo = https://api.github.com/repos/cburkins/poc-oidc-bare-javascript-boostrap3
# Searching for auth files for repo = https://api.github.com/repos/Sabrinalulu/NotesMan
# auth file = auth-callback.component.spec.ts found for repo = NotesMan
# auth file = auth-callback.component.ts found for repo = NotesMan
# auth file = auth-logout.component.spec.ts found for repo = NotesMan
# auth file = auth-logout.component.ts found for repo = NotesMan
# auth file = auth-guard.service.spec.ts found for repo = NotesMan
# auth file = auth-guard.service.ts found for repo = NotesMan
# auth file = auth-service.service.spec.ts found for repo = NotesMan
# auth file = auth-service.service.ts found for repo = NotesMan
# auth file = authentication.service.spec.ts found for repo = NotesMan
# auth file = authentication.service.ts found for repo = NotesMan
# Searching for auth files for repo = https://api.github.com/repos/maxmantz/redux-oidc-example
# Searching for auth files for repo = https://api.github.com/repos/jxjjligang/node-React-Renter
# Searching for auth files for repo = https://api.github.com/repos/DaIgeb/points
# Searching for auth files for repo = https://api.github.com/repos/jdority/headless-b2b-commerce
# Searching for auth files for repo = https://api.github.com/repos/nguyenlephong/jwt-api-build-router
# Searching for auth files for repo = https://api.github.com/repos/aymanokas/scoopstudio
# auth file = auth.js found for repo = scoopstudio
# Searching for auth files for repo = https://api.github.com/repos/arpit-simpos/agora
# auth file = login.service.js found for repo = agora
# Searching for auth files for repo = https://api.github.com/repos/patdx/device-code-login-test
# Searching for auth files for repo = https://api.github.com/repos/nnnhi/eMarkerApp
# auth file = auth.service.js found for repo = eMarkerApp
# Searching for auth files for repo = https://api.github.com/repos/novelar/pidy-app
# auth file = auth.guard.spec.ts found for repo = pidy-app
# auth file = auth.guard.ts found for repo = pidy-app
# auth file = auth.service.spec.ts found for repo = pidy-app
# auth file = auth.service.ts found for repo = pidy-app
# Searching for auth files for repo = https://api.github.com/repos/abgov/nx-tools-example
# Searching for auth files for repo = https://api.github.com/repos/project-belligerence/Belligerence
# Searching for auth files for repo = https://api.github.com/repos/defiantgoat/woowoofund-app
# Searching for auth files for repo = https://api.github.com/repos/nhsconnect/prm-deductions-portal-gp-practice
# auth file = auth-router.js found for repo = prm-deductions-portal-gp-practice
# auth file = authenticationService.js found for repo = prm-deductions-portal-gp-practice
# auth file = authenticationService.test.js found for repo = prm-deductions-portal-gp-practice
# auth file = oidcService.js found for repo = prm-deductions-portal-gp-practice
# Searching for auth files for repo = https://api.github.com/repos/pthpv95/vue-realtime-chat-app
# Searching for auth files for repo = https://api.github.com/repos/serverwentdown/chronos
# Searching for auth files for repo = https://api.github.com/repos/spurreiter/oidc-connector
# Searching for auth files for repo = https://api.github.com/repos/wangjunkai/hex
# Searching for auth files for repo = https://api.github.com/repos/Kaustix/Pomodoro
# Searching for auth files for repo = https://api.github.com/repos/N2AM/bawbty
# Searching for auth files for repo = https://api.github.com/repos/medaminehamidi/scoop
# auth file = auth.js found for repo = scoop
# Searching for auth files for repo = https://api.github.com/repos/KevalSikligar/workwyse
# Searching for auth files for repo = https://api.github.com/repos/ensembleVideo/ev-script
# Searching for auth files for repo = https://api.github.com/repos/dedreira/vue-base-project
# Searching for auth files for repo = https://api.github.com/repos/asadsahi/ngnode-fullstack
# auth file = auth.service.ts found for repo = ngnode-fullstack
# Searching for auth files for repo = https://api.github.com/repos/sivamaarutinc/Angular1006
# auth file = auth.service.ts found for repo = Angular1006
# auth file = continue-auth.service.spec.ts found for repo = Angular1006
# auth file = continue-auth.service.ts found for repo = Angular1006
# Searching for auth files for repo = https://api.github.com/repos/City-of-Helsinki/helerm-ui
# Searching for auth files for repo = https://api.github.com/repos/coralproject/cay
# Searching for auth files for repo = https://api.github.com/repos/zelixag/hex-nuxt
# Searching for auth files for repo = https://api.github.com/repos/olivermirimu/Netflux-mini-netflix-web-app-ALC
# Searching for auth files for repo = https://api.github.com/repos/dalorna/vueAA
# Searching for auth files for repo = https://api.github.com/repos/PointOnePercent/PointOnePercent
# Searching for auth files for repo = https://api.github.com/repos/Jacknes/9dashboard
# Searching for auth files for repo = https://api.github.com/repos/AnirudhSingal/FinApp_Public
# auth file = auth.config.ts found for repo = FinApp_Public
# auth file = auth.service.spec.ts found for repo = FinApp_Public
# auth file = auth.service.ts found for repo = FinApp_Public
# Searching for auth files for repo = https://api.github.com/repos/lmngtechteam/ElectronApp
# Searching for auth files for repo = https://api.github.com/repos/Bnei-Baruch/gxy-worldkli
# Searching for auth files for repo = https://api.github.com/repos/hcorazao/3d-conversion-software
# Searching for auth files for repo = https://api.github.com/repos/UN-OCHA/hpc-cdm
# Searching for auth files for repo = https://api.github.com/repos/dennismensah/AliasBankingWeb
# auth file = authcallback.component.spec.ts found for repo = AliasBankingWeb
# auth file = authcallback.component.ts found for repo = AliasBankingWeb
# auth file = authentication.service.ts found for repo = AliasBankingWeb
# auth file = oidc.service.ts found for repo = AliasBankingWeb
# Searching for auth files for repo = https://api.github.com/repos/gobberr/SDG-portal
# Searching for auth files for repo = https://api.github.com/repos/ch-luan2015/CL-CV
# Searching for auth files for repo = https://api.github.com/repos/ng-druid/platform
# Searching for auth files for repo = https://api.github.com/repos/City-of-Helsinki/linked-volunteering-ui
# auth file = authService.js found for repo = linked-volunteering-ui
# Searching for auth files for repo = https://api.github.com/repos/TheFeedBackNetwork/TFN.Frontend
# Searching for auth files for repo = https://api.github.com/repos/abgov/org-capacity-prototype
# Searching for auth files for repo = https://api.github.com/repos/stevensam0109/legal-disco-next-nest
# auth file = auth.controller.ts found for repo = legal-disco-next-nest
# auth file = auth.module.ts found for repo = legal-disco-next-nest
# auth file = auth.service.ts found for repo = legal-disco-next-nest
# auth file = login.guard.ts found for repo = legal-disco-next-nest
# auth file = oidc.strategy.ts found for repo = legal-disco-next-nest
# auth file = session-guard.ts found for repo = legal-disco-next-nest
# auth file = session.serializer.ts found for repo = legal-disco-next-nest
# Searching for auth files for repo = https://api.github.com/repos/jkaveri/react-redux-starter
# Searching for auth files for repo = https://api.github.com/repos/asadsahi/reactnode-fullstack
# auth file = auth.service.js found for repo = reactnode-fullstack
# Searching for auth files for repo = https://api.github.com/repos/Thyrse/Red_Tetris
# Searching for auth files for repo = https://api.github.com/repos/sijeong/avatar
# Searching for auth files for repo = https://api.github.com/repos/CrankHeart/trade-admin-webpack4
# Searching for auth files for repo = https://api.github.com/repos/guillaume-chervet/react-toolkit-old-demo
# Searching for auth files for repo = https://api.github.com/repos/GeoscienceAustralia/GNSS-Site-Manager
# Searching for auth files for repo = https://api.github.com/repos/suneta/PriceAlertLocal
# auth file = auth-callback.component.ts found for repo = PriceAlertLocal
# auth file = auth-guard.service.ts found for repo = PriceAlertLocal
# auth file = auth.service.ts found for repo = PriceAlertLocal
# Searching for auth files for repo = https://api.github.com/repos/BlueBrain/nexus-web
# Searching for auth files for repo = https://api.github.com/repos/linz/GNSS-Site-Manager
# Searching for auth files for repo = https://api.github.com/repos/City-of-Helsinki/kerrokantasi-ui
# Searching for auth files for repo = https://api.github.com/repos/zengenti/contensis-react-base
# Searching for auth files for repo = https://api.github.com/repos/MingyiLiang/Soochowco
# Searching for auth files for repo = https://api.github.com/repos/vijayasankar/ML2.0
# Searching for auth files for repo = https://api.github.com/repos/giantswarm/happa
# Searching for auth files for repo = https://api.github.com/repos/e1-bsd/omni-common-ui
# Searching for auth files for repo = https://api.github.com/repos/Onest-io/ONS-UI
# Searching for auth files for repo = https://api.github.com/repos/nbs-dex/nbs-ui
# Searching for auth files for repo = https://api.github.com/repos/lcklcntesasjksgd/rudex-ui
# Searching for auth files for repo = https://api.github.com/repos/lcklcntesasjksgd/loc-ui
# Searching for auth files for repo = https://api.github.com/repos/chadbernal/BLINCDEX
# Searching for auth files for repo = https://api.github.com/repos/KosmosOgKaos/island-is-fork
# auth file = auth.ts found for repo = island-is-fork
# Searching for auth files for repo = https://api.github.com/repos/bitshares/bitshares-ui
# Searching for auth files for repo = https://api.github.com/repos/makermadecnc/makerverse
# Searching for auth files for repo = https://api.github.com/repos/island-is/island.is
# auth file = auth.ts found for repo = island.is
# 403 {"documentation_url": "https://docs.github.com/en/free-pro-team@latest/rest/overview/resources-in-the-rest-api#secondary-rate-limits", "message": "You have exceeded a secondary rate limit. Please wait a few minutes before you try again."}

# %%
summer = 0
loc_array = []
n = 0
for repo, auth_files in repo_to_auth_files.items():
    for file, loc in auth_files:
        loc_array.append(loc)
        summer += loc
        n += 1

# %%
print(summer/n)
print(statistics.mean(loc_array))
print(statistics.median(loc_array))
print(min(loc_array))
print(max(loc_array))
print(sum(loc_array))
# Out:
# 45.44230769230769
# 45.44230769230769
# 25.5
# 5
# 280
# 2363
